# %% [markdown]
# # Importy

# %%
import os
import glob
import numpy as np
import matplotlib as plt
from scipy.io import wavfile
from numpy.random import randint
import ikrlib
import os
import glob
import pickle
import numpy as np
import ikrlib 
from sklearn.mixture import GaussianMixture
from sklearn.exceptions import ConvergenceWarning
import joblib
import os

# %% [markdown]
# # definicie

# %%
# constanty ---
MODEL_DIR = 'modelsAudio'
AUDIO_NUM_GAUSSIANS = 8  
AUDIO_EM_ITERATIONS = 20 
USE_DIAGONAL_COV = False 
os.makedirs(MODEL_DIR, exist_ok=True)
np.random.seed(29) #randint, nech sa nepokazi ratanie

# %% [markdown]
# # ulozenie a nacitanie modelov

# %%
def save_model(model, filename):
    try:
        joblib.dump(model, filename)
        print(f"Saved {filename}")
    except Exception as e:
        print(f"Error saving model: {e}")

def load_model(filename):
    if not os.path.exists(filename):
        print(f"{filename} not found.")
        return None
    try:
        model = joblib.load(filename)
        print(f"Model loaded {filename}")
        return model
    except Exception as e:
        print(f"Error loading model: {e}")
        return None

# %% [markdown]
# # pre-processing

# %%
def filter_silence(mfcc_features, energy_threshold=0.10):
   
    if mfcc_features is None or mfcc_features.shape[0] == 0:
        return mfcc_features
    

    energy = mfcc_features[:, 0]
    energy_normalized = (energy - np.min(energy)) / (np.max(energy) - np.min(energy) + 1e-10)
    

    voiced_frames = energy_normalized > energy_threshold
    

    if np.any(voiced_frames):
        return mfcc_features[voiced_frames, :]
    else:
        top_frames = max(1, int(0.2 * mfcc_features.shape[0]))
        top_indices = np.argsort(energy_normalized)[-top_frames:]
        return mfcc_features[top_indices, :]


def classify_audio(features, gmm_models):
    "klasifikovanie priznakov z MFFC , predikujem najprav. classu"
    best_score = -np.inf
    best_class = None

    if features is None or features.shape[0] == 0:
         return -1

    for class_id, gmm in gmm_models.items():
        if gmm is not None:
            try:
                # log prav na vzorku 
                avg_log_likelihood = gmm.score(features)

                # ak je lepsie, aktualizujeme do best score a class
                if avg_log_likelihood > best_score:
                    best_score = avg_log_likelihood
                    best_class = class_id
            except Exception as e:
                # ak nesedia dimenzie
                continue

    # ak sa nenasla trieda
    if best_class is None:
        return -1 

    return best_class

def extract_mfcc_features_for_classes(base_dir, class_ids=range(1, 32)):
   
    mfcc_features_by_class = {i: [] for i in class_ids}

    for class_id in class_ids:
        class_dir = os.path.join(base_dir, str(class_id))
        wav_files_in_class = []

        if os.path.isdir(class_dir):
            wav_files_in_class = glob.glob(os.path.join(class_dir, '*.wav'))

        if not wav_files_in_class:
            continue 
        
        mfcc_dict = ikrlib.wav16khz2mfcc(class_dir)
        class_features = []
        for wav_path in wav_files_in_class:
            if wav_path in mfcc_dict:
                mfcc_data = mfcc_dict[wav_path]

                if mfcc_data is not None and mfcc_data.shape[0] > 0:
                    processed_data = filter_silence(mfcc_data)
                    # vysledok

                    class_features.append(processed_data)

        mfcc_features_by_class[class_id] = class_features

    return mfcc_features_by_class

# %% [markdown]
# # trening gaussovky

# %%
def train_single_gmm_model_sklearn(all_features_for_class, num_gaussians, num_iterations, use_diag_cov):
    "scikit learn trening jedneho gmm modelu"
    if all_features_for_class is None or all_features_for_class.shape[0] < num_gaussians:
        print(f"Varovanie: Nedostatok dát pre trénovanie GMM ({all_features_for_class.shape[0] if all_features_for_class is not None else 0} vzoriek, potrebných aspoň {num_gaussians}). Preskakujem.")
        return None

    # Určenie typu kovariančnej matice pre scikit-learn
    covariance_type = 'diag' if use_diag_cov else 'full'

    try:
        # trenovanie
        gmm = GaussianMixture(
            n_components=num_gaussians,
            covariance_type=covariance_type,
            max_iter=num_iterations,
            n_init=1,
            random_state=29,
            reg_covar=1e-6, # singular matice fix error
            verbose=0,  
            verbose_interval=10
        )
        gmm.fit(all_features_for_class)

        print(f"GMM model natrénovaný. Log-likelihood: {gmm.lower_bound_:.4f}") # lower bound je approx. log-likelihood
        return gmm 

    except Exception as e:
        print(e)
        return None
    

def train_all_gmm_models_sklearn(mfcc_data_dict, num_gauss, num_iter, use_diag):
    "gmm modely vsetky pre kazdu triedu"
    print("train_all_gmm_models_sklearn debug start\n")
    audio_gmms = {}
#jednoduchy foreach cez jednotlive classy, kde spajam priznaky a natrenujem gmm na nich
    for class_id in range(1, 32):
        mfcc_list_for_class = mfcc_data_dict.get(class_id, [])

        valid_mfcc_list = []
        for mfcc in mfcc_list_for_class:
            if mfcc is not None and mfcc.shape[0] > 0:
                valid_mfcc_list.append(mfcc)

        if not valid_mfcc_list:
            audio_gmms[class_id] = None
            continue

        all_features_for_class = np.vstack(valid_mfcc_list)
        print(f"trenovanie - trieda{class_id}, ma {all_features_for_class.shape[0]} features...")
        gmm = train_single_gmm_model_sklearn(all_features_for_class, num_gauss, num_iter, use_diag)
        audio_gmms[class_id] = gmm 

    return audio_gmms

# %% [markdown]
# # testovacie funkcie, evaulacia

# %%
def test_gmm_model():
    # load
    model_filename = f'audio_gmm_{AUDIO_NUM_GAUSSIANS}g_{AUDIO_EM_ITERATIONS}i{USE_DIAGONAL_COV}.pkl'
    AUDIO_GMM_MODEL_FILE = os.path.join(MODEL_DIR, model_filename)
    trained_audio_gmms = load_model(AUDIO_GMM_MODEL_FILE)
    
    if not trained_audio_gmms:
        return
    
    # extract
    test_mfcc_data =extract_mfcc_features_for_classes(base_dir="test")
    
    # Eval
    total_correct = 0
    total_samples = 0
    class_stats = {i: {'correct': 0, 'total': 0} for i in range(1, 32)}
    
    print("\nTesting GMM models...")
    
    for true_class, features_list in test_mfcc_data.items():
        for features in features_list:
            if features is not None and features.shape[0] > 0:
                # Classify the sample
                pred_class = classify_audio(features, trained_audio_gmms)
                
                # pridam jedno do celkovych
                class_stats[true_class]['total'] += 1
                if pred_class == true_class:
                    total_correct += 1
                    class_stats[true_class]['correct'] += 1 #pridam jedno ak spravne
                total_samples += 1
    
    accuracy = total_correct / total_samples if total_samples > 0 else 0 #celkova presnost
    
    print(f"\nvysledky modelu")
    print(f"presnost {accuracy * 100:.2f}%")
    
    print("\npresnost class:") #per class , correct / total pre kazdy array prvok 
    for class_id in sorted(class_stats.keys()):
        total = class_stats[class_id]['total']
        correct = class_stats[class_id]['correct']
        if total > 0:
            class_accuracy = correct / total
            print(f"class {class_id}: {class_accuracy * 100:.2f}%")

# %%
def process_test_wav_files_sklearn(test_dir, gmm_models, output_file):
    """Spracuje wav subory, klasifikuje a zaroven vyhodnoti ulozi"""
    
    # Extrakcia MFCC
    test_mfcc_data = extract_mfcc_features_for_classes(test_dir)
    
    results = []
    total_correct = 0
    total_samples = 0

    print(f"\nSpracovanie testovacích súborov v adresári: {test_dir}")
    
    # each class
    for class_id, features_list in test_mfcc_data.items():
        class_dir = os.path.join(test_dir, str(class_id))
        mfcc_dict = ikrlib.wav16khz2mfcc(class_dir)
        
        # nazvy suborov
        file_paths = list(mfcc_dict.keys())
        
        for idx, features in enumerate(features_list):
          
            if idx < len(file_paths):
                
                file_name = os.path.splitext(os.path.basename(file_paths[idx]))[0]
            else:
                file_name = f"class_{class_id}_sample_{idx}"
            
            if features is not None and features.shape[0] > 0:
                # klasifikac
                predicted_class = classify_audio(features, gmm_models)
                
                # skore
                scores = []
                for i in range(1, 32):
                    if i in gmm_models and gmm_models[i] is not None:
                        try:
                            score = gmm_models[i].score(features)
                            scores.append(score)
                        except:
                            scores.append(float('-inf'))
                    else:
                        scores.append(float('-inf'))
                
                results.append((file_name, predicted_class, scores))
                
                # aktualizacia
                if predicted_class == class_id:
                    total_correct += 1
                total_samples += 1
            else:
                # osetrenie
                print(f"Varovanie: Prázdne príznaky pre súbor {file_name}")
                results.append((file_name, -1, [float('-inf')] * 31))
                total_samples += 1
    
    # zapis do suboru
    print(f"\nZapisujem výsledky do súboru: {output_file}")
    with open(output_file, 'w') as f:
        for file_name, pred_class, score_values in results:
            score_str = ' '.join([f"{score:.6f}" for score in score_values])
            f.write(f"{file_name} {pred_class} {score_str}\n")
    
    # vypis presnosti
    if total_samples > 0:
        accuracy = total_correct / total_samples
        print(f"\nvysledky:")
        print(f"presnost total {accuracy * 100:.2f}% ({total_correct}/{total_samples})")
    else:
        print("\n0")
    
    return results

# %% [markdown]
# # TRENOVANIE MAIN

# %%
print("Pipeline pre trénovanie audio modelu (scikit-learn GMM)...")

# EXTRAKCIA PRIZNAKOV MFCC
train_mfcc_data = train_mfcc_data = extract_mfcc_features_for_classes(base_dir="train") # Táto funkcia by mala volať filter_silence

# DEFINICIA MENA MODELU NA ULOZENIE DO ModelsAUDIO
model_filename = f'audio_gmm_sklearn_{AUDIO_NUM_GAUSSIANS}g_{AUDIO_EM_ITERATIONS}i{"diag" if USE_DIAGONAL_COV else "full"}.pkl'
AUDIO_GMM_MODEL_FILE = os.path.join(MODEL_DIR, model_filename)

# trening modelov

trained_audio_gmms_sklearn = train_all_gmm_models_sklearn(
    train_mfcc_data,
    AUDIO_NUM_GAUSSIANS,
    AUDIO_EM_ITERATIONS,
    USE_DIAGONAL_COV
)

#ulozenie modelu na pouzitie 

save_model(trained_audio_gmms_sklearn, AUDIO_GMM_MODEL_FILE)


print("\nPipeline pre trénovanie audio modelu (scikit-learn GMM) dokončená.")
# Out:
# Pipeline pre trénovanie audio modelu (scikit-learn GMM)...
# Processing file:  train\1\f401_01_f12_i0_0.wav
# Processing file:  train\1\f401_01_p01_i0_0.wav
# Processing file:  train\1\f401_02_f12_i0_0.wav
# Processing file:  train\1\f401_02_p01_i0_0.wav
# Processing file:  train\1\f401_03_f12_i0_0.wav
# Processing file:  train\1\f401_03_p01_i0_0.wav
# Processing file:  train\2\f402_01_f12_i0_0.wav
# Processing file:  train\2\f402_01_p01_i0_0.wav
# Processing file:  train\2\f402_02_f12_i0_0.wav
# Processing file:  train\2\f402_02_p01_i0_0.wav
# Processing file:  train\2\f402_03_f12_i0_0.wav
# Processing file:  train\2\f402_03_p01_i0_0.wav
# Processing file:  train\3\f403_01_f12_i0_0.wav
# Processing file:  train\3\f403_01_p01_i0_0.wav
# Processing file:  train\3\f403_02_f12_i0_0.wav
# Processing file:  train\3\f403_02_p01_i0_0.wav
# Processing file:  train\3\f403_03_f12_i0_0.wav
# Processing file:  train\3\f403_03_p01_i0_0.wav
# Processing file:  train\4\f404_01_f12_i0_0.wav
# Processing file:  train\4\f404_01_p01_i0_0.wav
# Processing file:  train\4\f404_02_f12_i0_0.wav
# Processing file:  train\4\f404_02_p01_i0_0.wav
# Processing file:  train\4\f404_03_f12_i0_0.wav
# Processing file:  train\4\f404_03_p01_i0_0.wav
# Processing file:  train\5\f405_01_f12_i0_0.wav
# Processing file:  train\5\f405_01_p01_i0_0.wav
# Processing file:  train\5\f405_02_f12_i0_0.wav
# Processing file:  train\5\f405_02_p01_i0_0.wav
# Processing file:  train\5\f405_03_f12_i0_0.wav
# Processing file:  train\5\f405_03_p01_i0_0.wav
# Processing file:  train\6\f406_01_f12_i0_0.wav
# Processing file:  train\6\f406_01_p01_i0_0.wav
# Processing file:  train\6\f406_02_f12_i0_0.wav
# Processing file:  train\6\f406_02_p01_i0_0.wav
# Processing file:  train\6\f406_03_p01_i0_0.wav
# Processing file:  train\6\f406_03_r06_i0_0.wav
# Processing file:  train\7\f407_01_f12_i0_0.wav
# Processing file:  train\7\f407_01_p01_i0_0.wav
# Processing file:  train\7\f407_02_f12_i0_0.wav
# Processing file:  train\7\f407_02_p01_i0_0.wav
# Processing file:  train\7\f407_03_f12_i0_0.wav
# Processing file:  train\7\f407_03_p01_i0_0.wav
# Processing file:  train\8\f408_01_f12_i0_0.wav
# Processing file:  train\8\f408_01_p01_i0_0.wav
# Processing file:  train\8\f408_02_f12_i0_0.wav
# Processing file:  train\8\f408_02_p01_i0_0.wav
# Processing file:  train\8\f408_03_f12_i0_0.wav
# Processing file:  train\8\f408_03_p01_i0_0.wav
# Processing file:  train\9\f409_01_f12_i0_0.wav
# Processing file:  train\9\f409_01_p01_i0_0.wav
# Processing file:  train\9\f409_02_f12_i0_0.wav
# Processing file:  train\9\f409_02_p01_i0_0.wav
# Processing file:  train\9\f409_03_f12_i0_0.wav
# Processing file:  train\9\f409_03_p01_i0_0.wav
# Processing file:  train\10\f410_01_f12_i0_0.wav
# Processing file:  train\10\f410_01_p01_i0_0.wav
# Processing file:  train\10\f410_02_f21_i0_0.wav
# Processing file:  train\10\f410_02_p01_i0_0.wav
# Processing file:  train\10\f410_03_f12_i0_0.wav
# Processing file:  train\10\f410_03_p01_i0_0.wav
# Processing file:  train\11\f411_01_f12_i0_0.wav
# Processing file:  train\11\f411_01_r06_i0_0.wav
# Processing file:  train\11\f411_02_f12_i0_0.wav
# Processing file:  train\11\f411_02_p01_i0_0.wav
# Processing file:  train\11\f411_03_f12_i0_0.wav
# Processing file:  train\11\f411_03_p01_i0_0.wav
# Processing file:  train\12\f412_01_f12_i0_0.wav
# Processing file:  train\12\f412_01_p01_i0_0.wav
# Processing file:  train\12\f412_02_f12_i0_0.wav
# Processing file:  train\12\f412_02_p01_i0_0.wav
# Processing file:  train\12\f412_03_f12_i0_0.wav
# Processing file:  train\12\f412_03_p01_i0_0.wav
# Processing file:  train\13\f413_01_f12_i0_0.wav
# Processing file:  train\13\f413_01_p01_i0_0.wav
# Processing file:  train\13\f413_02_f12_i0_0.wav
# Processing file:  train\13\f413_02_p01_i0_0.wav
# Processing file:  train\13\f413_03_f12_i0_0.wav
# Processing file:  train\13\f413_03_p01_i0_0.wav
# Processing file:  train\14\f415_01_f12_i0_0.wav
# Processing file:  train\14\f415_01_p01_i0_0.wav
# Processing file:  train\14\f415_02_f12_i0_0.wav
# Processing file:  train\14\f415_02_p01_i0_0.wav
# Processing file:  train\14\f415_03_f12_i0_0.wav
# Processing file:  train\14\f415_03_p01_i0_0.wav
# Processing file:  train\15\f433_01_f12_i0_0.wav
# Processing file:  train\15\f433_01_p01_i0_0.wav
# Processing file:  train\15\f433_02_f12_i0_0.wav
# Processing file:  train\15\f433_02_p01_i0_0.wav
# Processing file:  train\15\f433_03_f12_i0_0.wav
# Processing file:  train\15\f433_03_p01_i0_0.wav
# Processing file:  train\16\m414_01_f12_i0_0.wav
# Processing file:  train\16\m414_01_p01_i0_0.wav
# Processing file:  train\16\m414_02_f12_i0_0.wav
# Processing file:  train\16\m414_02_p01_i0_0.wav
# Processing file:  train\16\m414_03_f12_i0_0.wav
# Processing file:  train\16\m414_03_p01_i0_0.wav
# Processing file:  train\17\m417_01_f12_i0_0.wav
# Processing file:  train\17\m417_01_p01_i0_0.wav
# Processing file:  train\17\m417_02_f12_i0_0.wav
# Processing file:  train\17\m417_02_p01_i0_0.wav
# Processing file:  train\17\m417_03_f12_i0_0.wav
# Processing file:  train\17\m417_03_p01_i0_0.wav
# Processing file:  train\18\m419_01_f12_i0_0.wav
# Processing file:  train\18\m419_01_p01_i0_0.wav
# Processing file:  train\18\m419_02_f12_i0_0.wav
# Processing file:  train\18\m419_02_p01_i0_0.wav
# Processing file:  train\18\m419_03_f12_i0_0.wav
# Processing file:  train\18\m419_03_p01_i0_0.wav
# Processing file:  train\19\m420_01_f12_i0_0.wav
# Processing file:  train\19\m420_01_p01_i0_0.wav
# Processing file:  train\19\m420_02_f12_i0_0.wav
# Processing file:  train\19\m420_02_p01_i0_0.wav
# Processing file:  train\19\m420_03_f12_i0_0.wav
# Processing file:  train\19\m420_03_p01_i0_0.wav
# Processing file:  train\20\m421_01_f12_i0_0.wav
# Processing file:  train\20\m421_01_p01_i0_0.wav
# Processing file:  train\20\m421_02_f12_i0_0.wav
# Processing file:  train\20\m421_02_p01_i0_0.wav
# Processing file:  train\20\m421_03_f12_i0_0.wav
# Processing file:  train\20\m421_03_p01_i0_0.wav
# Processing file:  train\21\m422_01_f12_i0_0.wav
# Processing file:  train\21\m422_01_p01_i0_0.wav
# Processing file:  train\21\m422_02_f12_i0_0.wav
# Processing file:  train\21\m422_02_p01_i0_0.wav
# Processing file:  train\21\m422_03_f12_i0_0.wav
# Processing file:  train\21\m422_03_p01_i0_0.wav
# Processing file:  train\22\m423_01_f12_i0_0.wav
# Processing file:  train\22\m423_01_p01_i0_0.wav
# Processing file:  train\22\m423_02_f12_i0_0.wav
# Processing file:  train\22\m423_02_p01_i0_0.wav
# Processing file:  train\22\m423_03_f12_i0_0.wav
# Processing file:  train\22\m423_03_p01_i0_0.wav
# Processing file:  train\23\m424_01_f12_i0_0.wav
# Processing file:  train\23\m424_01_p01_i0_0.wav
# Processing file:  train\23\m424_02_f12_i0_0.wav
# Processing file:  train\23\m424_02_p01_i0_0.wav
# Processing file:  train\23\m424_03_f12_i0_0.wav
# Processing file:  train\23\m424_03_p01_i0_0.wav
# Processing file:  train\24\m425_01_f12_i0_0.wav
# Processing file:  train\24\m425_01_p01_i0_0.wav
# Processing file:  train\24\m425_02_f12_i0_0.wav
# Processing file:  train\24\m425_02_p01_i0_0.wav
# Processing file:  train\24\m425_03_f12_i0_0.wav
# Processing file:  train\24\m425_03_p01_i0_0.wav
# Processing file:  train\25\m426_01_f12_i0_0.wav
# Processing file:  train\25\m426_01_p01_i0_0.wav
# Processing file:  train\25\m426_02_f12_i0_0.wav
# Processing file:  train\25\m426_02_p01_i0_0.wav
# Processing file:  train\25\m426_03_f12_i0_0.wav
# Processing file:  train\25\m426_03_p01_i0_0.wav
# Processing file:  train\26\m427_01_f12_i0_0.wav
# Processing file:  train\26\m427_01_p01_i0_0.wav
# Processing file:  train\26\m427_02_f12_i0_0.wav
# Processing file:  train\26\m427_02_p01_i0_0.wav
# Processing file:  train\26\m427_03_f12_i0_0.wav
# Processing file:  train\26\m427_03_p01_i0_0.wav
# Processing file:  train\27\m428_01_f12_i0_0.wav
# Processing file:  train\27\m428_01_p01_i0_0.wav
# Processing file:  train\27\m428_02_f12_i0_0.wav
# Processing file:  train\27\m428_02_p01_i0_0.wav
# Processing file:  train\27\m428_03_f12_i0_0.wav
# Processing file:  train\27\m428_03_p01_i0_0.wav
# Processing file:  train\28\m429_01_f12_i0_0.wav
# Processing file:  train\28\m429_01_p01_i0_0.wav
# Processing file:  train\28\m429_02_f12_i0_0.wav
# Processing file:  train\28\m429_02_p01_i0_0.wav
# Processing file:  train\28\m429_03_f12_i0_0.wav
# Processing file:  train\28\m429_03_p01_i0_0.wav
# Processing file:  train\29\m430_01_f12_i0_0.wav
# Processing file:  train\29\m430_01_p01_i0_0.wav
# Processing file:  train\29\m430_02_f12_i0_0.wav
# Processing file:  train\29\m430_02_p01_i0_0.wav
# Processing file:  train\29\m430_03_f12_i0_0.wav
# Processing file:  train\29\m430_03_p01_i0_0.wav
# Processing file:  train\30\m431_01_f12_i0_0.wav
# Processing file:  train\30\m431_01_p01_i0_0.wav
# Processing file:  train\30\m431_02_f12_i0_0.wav
# Processing file:  train\30\m431_02_p01_i0_0.wav
# Processing file:  train\30\m431_03_f12_i0_0.wav
# Processing file:  train\30\m431_03_p01_i0_0.wav
# Processing file:  train\31\m432_01_f12_i0_0.wav
# Processing file:  train\31\m432_01_p01_i0_0.wav
# Processing file:  train\31\m432_02_f12_i0_0.wav
# Processing file:  train\31\m432_02_p01_i0_0.wav
# Processing file:  train\31\m432_03_f12_i0_0.wav
# Processing file:  train\31\m432_03_p01_i0_0.wav
# train_all_gmm_models_sklearn debug start
#
# trenovanie - trieda1, ma 10375 features...
# GMM model natrénovaný. Log-likelihood: -7.9146
# trenovanie - trieda2, ma 8630 features...
# GMM model natrénovaný. Log-likelihood: -8.1696
# trenovanie - trieda3, ma 7619 features...
# GMM model natrénovaný. Log-likelihood: -7.3439
# trenovanie - trieda4, ma 6165 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -7.1557
# trenovanie - trieda5, ma 7902 features...
# GMM model natrénovaný. Log-likelihood: -8.3259
# trenovanie - trieda6, ma 6614 features...
# GMM model natrénovaný. Log-likelihood: -7.2480
# trenovanie - trieda7, ma 5393 features...
# GMM model natrénovaný. Log-likelihood: -6.8909
# trenovanie - trieda8, ma 6862 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -6.7735
# trenovanie - trieda9, ma 6532 features...
# GMM model natrénovaný. Log-likelihood: -8.3078
# trenovanie - trieda10, ma 6267 features...
# GMM model natrénovaný. Log-likelihood: -8.0559
# trenovanie - trieda11, ma 5804 features...
# GMM model natrénovaný. Log-likelihood: -6.8995
# trenovanie - trieda12, ma 5899 features...
# GMM model natrénovaný. Log-likelihood: -6.4288
# trenovanie - trieda13, ma 9180 features...
# GMM model natrénovaný. Log-likelihood: -7.0947
# trenovanie - trieda14, ma 7281 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -6.7068
# trenovanie - trieda15, ma 6467 features...
# GMM model natrénovaný. Log-likelihood: -6.1887
# trenovanie - trieda16, ma 5552 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -6.7782
# trenovanie - trieda17, ma 8393 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -8.6285
# trenovanie - trieda18, ma 7337 features...
# GMM model natrénovaný. Log-likelihood: -7.9073
# trenovanie - trieda19, ma 6085 features...
# GMM model natrénovaný. Log-likelihood: -7.8592
# trenovanie - trieda20, ma 5998 features...
# GMM model natrénovaný. Log-likelihood: -6.5899
# trenovanie - trieda21, ma 8569 features...
# GMM model natrénovaný. Log-likelihood: -8.2036
# trenovanie - trieda22, ma 9542 features...
# GMM model natrénovaný. Log-likelihood: -8.2734
# trenovanie - trieda23, ma 6402 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -6.6969
# trenovanie - trieda24, ma 7568 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -7.4995
# trenovanie - trieda25, ma 6801 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -6.4551
# trenovanie - trieda26, ma 19545 features...
# GMM model natrénovaný. Log-likelihood: -7.9879
# trenovanie - trieda27, ma 6293 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -8.4904
# trenovanie - trieda28, ma 6672 features...
# GMM model natrénovaný. Log-likelihood: -6.7943
# trenovanie - trieda29, ma 9433 features...
# GMM model natrénovaný. Log-likelihood: -7.0213
# trenovanie - trieda30, ma 6020 features...
# c:\Users\2karo\vscode_projects\sur\.venv\Lib\site-packages\sklearn\mixture\_base.py:269: ConvergenceWarning: Best performing initialization did not converge. Try different init parameters, or increase max_iter, tol, or check for degenerate data.
#   warnings.warn(
# GMM model natrénovaný. Log-likelihood: -6.9094
# trenovanie - trieda31, ma 6558 features...
# GMM model natrénovaný. Log-likelihood: -6.5619
# Saved modelsAudio\audio_gmm_sklearn_8g_20ifull.pkl
#
# Pipeline pre trénovanie audio modelu (scikit-learn GMM) dokončená.

# %% [markdown]
# # TESTOVANIE MAIN

# %%
print("\nTESTOVANIE EVAL")

# LOAD MODEL
model_path = AUDIO_GMM_MODEL_FILE 
trained_gmms_loaded = load_model(model_path)


print(f"pocet tried debug {len(trained_gmms_loaded)}")
# 2. Definovanie testovacieho adresára a výstupného súboru
test_dir = "test"  # Adresár s evaluačnými dátami
output_file = "audio_GMM_sklearntest.txt"  # Názov výstupného súboru
train_dir = "train"  # Adresár s evaluačnými dátami
output_file_train = "audio_GMM_sklearntrain.txt"
# 3. Spustenie spracovania testovacích súborov
process_test_wav_files_sklearn(test_dir, trained_gmms_loaded, output_file)
#rocess_test_wav_files_sklearn(train_dir, trained_gmms_loaded, output_file_train)
print(output_file)
# Out:
# TESTOVANIE EVAL
# Model loaded modelsAudio\audio_gmm_sklearn_8g_20ifull.pkl
# pocet tried debug 31
# Processing file:  test\1\f401_04_f12_i0_0.wav
# Processing file:  test\1\f401_04_p01_i0_0.wav
# Processing file:  test\2\f402_04_f12_i0_0.wav
# Processing file:  test\2\f402_04_p01_i0_0.wav
# Processing file:  test\3\f403_04_f12_i0_0.wav
# Processing file:  test\3\f403_04_p01_i0_0.wav
# Processing file:  test\4\f404_04_f12_i0_0.wav
# Processing file:  test\4\f404_04_p01_i0_0.wav
# Processing file:  test\5\f405_04_f12_i0_0.wav
# Processing file:  test\5\f405_04_p01_i0_0.wav
# Processing file:  test\6\f406_04_f12_i0_0.wav
# Processing file:  test\6\f406_04_p01_i0_0.wav
# Processing file:  test\7\f407_04_f12_i0_0.wav
# Processing file:  test\7\f407_04_p01_i0_0.wav
# Processing file:  test\8\f408_04_f12_i0_0.wav
# Processing file:  test\8\f408_04_p01_i0_0.wav
# Processing file:  test\9\f409_04_f12_i0_0.wav
# Processing file:  test\9\f409_04_p01_i0_0.wav
# Processing file:  test\10\f410_04_f12_i0_0.wav
# Processing file:  test\10\f410_04_p01_i0_0.wav
# Processing file:  test\11\f411_04_f12_i0_0.wav
# Processing file:  test\11\f411_04_p01_i0_0.wav
# Processing file:  test\12\f412_04_f12_i0_0.wav
# Processing file:  test\12\f412_04_p01_i0_0.wav
# Processing file:  test\13\f413_04_f12_i0_0.wav
# Processing file:  test\13\f413_04_p01_i0_0.wav
# Processing file:  test\14\f415_04_f12_i0_0.wav
# Processing file:  test\14\f415_04_p01_i0_0.wav
# Processing file:  test\15\f433_04_f12_i0_0.wav
# Processing file:  test\15\f433_04_p01_i0_0.wav
# Processing file:  test\16\m414_04_p01_i0_0.wav
# Processing file:  test\16\m414_04_r06_i0_0.wav
# Processing file:  test\17\m417_04_f12_i0_0.wav
# Processing file:  test\17\m417_04_p01_i0_0.wav
# Processing file:  test\18\m419_04_f12_i0_0.wav
# Processing file:  test\18\m419_04_p01_i0_0.wav
# Processing file:  test\19\m420_04_f12_i0_0.wav
# Processing file:  test\19\m420_04_p01_i0_0.wav
# Processing file:  test\20\m421_04_f12_i0_0.wav
# Processing file:  test\20\m421_04_p01_i0_0.wav
# Processing file:  test\21\m422_04_p01_i0_0.wav
# Processing file:  test\21\m422_04_r06_i0_0.wav
# Processing file:  test\22\m423_04_f12_i0_0.wav
# Processing file:  test\22\m423_04_p01_i0_0.wav
# Processing file:  test\23\m424_04_f12_i0_0.wav
# Processing file:  test\23\m424_04_p01_i0_0.wav
# Processing file:  test\24\m425_04_f12_i0_0.wav
# Processing file:  test\24\m425_04_p01_i0_0.wav
# Processing file:  test\25\m426_04_f12_i0_0.wav
# Processing file:  test\25\m426_04_p01_i0_0.wav
# Processing file:  test\26\m427_04_f12_i0_0.wav
# Processing file:  test\26\m427_04_p01_i0_0.wav
# Processing file:  test\27\m428_04_f12_i0_0.wav
# Processing file:  test\27\m428_04_p01_i0_0.wav
# Processing file:  test\28\m429_04_f12_i0_0.wav
# Processing file:  test\28\m429_04_p01_i0_0.wav
# Processing file:  test\29\m430_04_f12_i0_0.wav
# Processing file:  test\29\m430_04_p01_i0_0.wav
# Processing file:  test\30\m431_04_f12_i0_0.wav
# Processing file:  test\30\m431_04_p01_i0_0.wav
# Processing file:  test\31\m432_04_f12_i0_0.wav
# Processing file:  test\31\m432_04_p01_i0_0.wav
#
# Spracovanie testovacích súborov v adresári: test
# Processing file:  test\1\f401_04_f12_i0_0.wav
# Processing file:  test\1\f401_04_p01_i0_0.wav
# Processing file:  test\2\f402_04_f12_i0_0.wav
# Processing file:  test\2\f402_04_p01_i0_0.wav
# Processing file:  test\3\f403_04_f12_i0_0.wav
# Processing file:  test\3\f403_04_p01_i0_0.wav
# Processing file:  test\4\f404_04_f12_i0_0.wav
# Processing file:  test\4\f404_04_p01_i0_0.wav
# Processing file:  test\5\f405_04_f12_i0_0.wav
# Processing file:  test\5\f405_04_p01_i0_0.wav
# Processing file:  test\6\f406_04_f12_i0_0.wav
# Processing file:  test\6\f406_04_p01_i0_0.wav
# Processing file:  test\7\f407_04_f12_i0_0.wav
# Processing file:  test\7\f407_04_p01_i0_0.wav
# Processing file:  test\8\f408_04_f12_i0_0.wav
# Processing file:  test\8\f408_04_p01_i0_0.wav
# Processing file:  test\9\f409_04_f12_i0_0.wav
# Processing file:  test\9\f409_04_p01_i0_0.wav
# Processing file:  test\10\f410_04_f12_i0_0.wav
# Processing file:  test\10\f410_04_p01_i0_0.wav
# Processing file:  test\11\f411_04_f12_i0_0.wav
# Processing file:  test\11\f411_04_p01_i0_0.wav
# Processing file:  test\12\f412_04_f12_i0_0.wav
# Processing file:  test\12\f412_04_p01_i0_0.wav
# Processing file:  test\13\f413_04_f12_i0_0.wav
# Processing file:  test\13\f413_04_p01_i0_0.wav
# Processing file:  test\14\f415_04_f12_i0_0.wav
# Processing file:  test\14\f415_04_p01_i0_0.wav
# Processing file:  test\15\f433_04_f12_i0_0.wav
# Processing file:  test\15\f433_04_p01_i0_0.wav
# Processing file:  test\16\m414_04_p01_i0_0.wav
# Processing file:  test\16\m414_04_r06_i0_0.wav
# Processing file:  test\17\m417_04_f12_i0_0.wav
# Processing file:  test\17\m417_04_p01_i0_0.wav
# Processing file:  test\18\m419_04_f12_i0_0.wav
# Processing file:  test\18\m419_04_p01_i0_0.wav
# Processing file:  test\19\m420_04_f12_i0_0.wav
# Processing file:  test\19\m420_04_p01_i0_0.wav
# Processing file:  test\20\m421_04_f12_i0_0.wav
# Processing file:  test\20\m421_04_p01_i0_0.wav
# Processing file:  test\21\m422_04_p01_i0_0.wav
# Processing file:  test\21\m422_04_r06_i0_0.wav
# Processing file:  test\22\m423_04_f12_i0_0.wav
# Processing file:  test\22\m423_04_p01_i0_0.wav
# Processing file:  test\23\m424_04_f12_i0_0.wav
# Processing file:  test\23\m424_04_p01_i0_0.wav
# Processing file:  test\24\m425_04_f12_i0_0.wav
# Processing file:  test\24\m425_04_p01_i0_0.wav
# Processing file:  test\25\m426_04_f12_i0_0.wav
# Processing file:  test\25\m426_04_p01_i0_0.wav
# Processing file:  test\26\m427_04_f12_i0_0.wav
# Processing file:  test\26\m427_04_p01_i0_0.wav
# Processing file:  test\27\m428_04_f12_i0_0.wav
# Processing file:  test\27\m428_04_p01_i0_0.wav
# Processing file:  test\28\m429_04_f12_i0_0.wav
# Processing file:  test\28\m429_04_p01_i0_0.wav
# Processing file:  test\29\m430_04_f12_i0_0.wav
# Processing file:  test\29\m430_04_p01_i0_0.wav
# Processing file:  test\30\m431_04_f12_i0_0.wav
# Processing file:  test\30\m431_04_p01_i0_0.wav
# Processing file:  test\31\m432_04_f12_i0_0.wav
# Processing file:  test\31\m432_04_p01_i0_0.wav
#
# Zapisujem výsledky do súboru: audio_GMM_sklearntest.txt
#
# vysledky:
# presnost total 72.58% (45/62)
# audio_GMM_sklearntest.txt

# %% [markdown]
# # update pre data eval strukturu

# %%
def process_eval_files_sklearn(eval_dir, gmm_models, output_file):
    """Spracuje wav subory v eval adresari, klasifikuje a ulozi"""
    import glob
    
    # Nájdeme všetky WAV súbory v eval adresári
    wav_files = glob.glob(os.path.join(eval_dir, '*.wav'))
    
    # Extrakcia MFCC príznakov
    mfcc_dict = ikrlib.wav16khz2mfcc(eval_dir)
    
    results = []
    
    print(f"\nSpracovanie súborov v eval adresári: {eval_dir}")
    
    for wav_path in wav_files:
        file_name = os.path.splitext(os.path.basename(wav_path))[0]
        raw_mfcc = mfcc_dict[wav_path]
        features = filter_silence(raw_mfcc)
        
        # Klasifikácia
        predicted_class = classify_audio(features, gmm_models)
        
        # Výpočet skóre pre všetky triedy
        scores = []
        for i in range(1, 32):
            score = gmm_models[i].score(features)
            scores.append(score)
        
        results.append((file_name, predicted_class, scores))
    
    # Zápis výsledkov do súboru
    with open(output_file, 'w') as f:
        for file_name, pred_class, score_values in results:
            score_str = ' '.join([f"{score:.6f}" for score in score_values])
            f.write(f"{file_name} {pred_class} {score_str}\n")
    
    return results

# %%
#pipeline
model_path = AUDIO_GMM_MODEL_FILE 
trained_gmms_loaded = load_model(model_path)

print(f"pocet tried debug {len(trained_gmms_loaded)}")

eval_dir = "eval"
output_file_eval = "audio_GMM_sklearn_eval.txt"

process_eval_files_sklearn(eval_dir, trained_gmms_loaded, output_file_eval)

print(f"Eval: {output_file_eval}")
# Out:
# Model loaded modelsAudio\audio_gmm_sklearn_8g_20ifull.pkl
# pocet tried debug 31
# Processing file:  eval\eval_00001.wav
# Processing file:  eval\eval_00002.wav
# Processing file:  eval\eval_00003.wav
# Processing file:  eval\eval_00004.wav
# Processing file:  eval\eval_00005.wav
# Processing file:  eval\eval_00006.wav
# Processing file:  eval\eval_00007.wav
# Processing file:  eval\eval_00008.wav
# Processing file:  eval\eval_00009.wav
# Processing file:  eval\eval_00010.wav
# Processing file:  eval\eval_00011.wav
# Processing file:  eval\eval_00012.wav
# Processing file:  eval\eval_00013.wav
# Processing file:  eval\eval_00014.wav
# Processing file:  eval\eval_00015.wav
# Processing file:  eval\eval_00016.wav
# Processing file:  eval\eval_00017.wav
# Processing file:  eval\eval_00018.wav
# Processing file:  eval\eval_00019.wav
# Processing file:  eval\eval_00020.wav
# Processing file:  eval\eval_00021.wav
# Processing file:  eval\eval_00022.wav
# Processing file:  eval\eval_00023.wav
# Processing file:  eval\eval_00024.wav
# Processing file:  eval\eval_00025.wav
# Processing file:  eval\eval_00026.wav
# Processing file:  eval\eval_00027.wav
# Processing file:  eval\eval_00028.wav
# Processing file:  eval\eval_00029.wav
# Processing file:  eval\eval_00030.wav
# Processing file:  eval\eval_00031.wav
# Processing file:  eval\eval_00032.wav
# Processing file:  eval\eval_00033.wav
# Processing file:  eval\eval_00034.wav
# Processing file:  eval\eval_00035.wav
# Processing file:  eval\eval_00036.wav
# Processing file:  eval\eval_00037.wav
# Processing file:  eval\eval_00038.wav
# Processing file:  eval\eval_00039.wav
# Processing file:  eval\eval_00040.wav
# Processing file:  eval\eval_00041.wav
# Processing file:  eval\eval_00042.wav
# Processing file:  eval\eval_00043.wav
# Processing file:  eval\eval_00044.wav
# Processing file:  eval\eval_00045.wav
# Processing file:  eval\eval_00046.wav
# Processing file:  eval\eval_00047.wav
# Processing file:  eval\eval_00048.wav
# Processing file:  eval\eval_00049.wav
# Processing file:  eval\eval_00050.wav
# Processing file:  eval\eval_00051.wav
# Processing file:  eval\eval_00052.wav
# Processing file:  eval\eval_00053.wav
# Processing file:  eval\eval_00054.wav
# Processing file:  eval\eval_00055.wav
# Processing file:  eval\eval_00056.wav
# Processing file:  eval\eval_00057.wav
# Processing file:  eval\eval_00058.wav
# Processing file:  eval\eval_00059.wav
# Processing file:  eval\eval_00060.wav
# Processing file:  eval\eval_00061.wav
# Processing file:  eval\eval_00062.wav
# Processing file:  eval\eval_00063.wav
# Processing file:  eval\eval_00064.wav
# Processing file:  eval\eval_00065.wav
# Processing file:  eval\eval_00066.wav
# Processing file:  eval\eval_00067.wav
# Processing file:  eval\eval_00068.wav
# Processing file:  eval\eval_00069.wav
# Processing file:  eval\eval_00070.wav
# Processing file:  eval\eval_00071.wav
# Processing file:  eval\eval_00072.wav
# Processing file:  eval\eval_00073.wav
# Processing file:  eval\eval_00074.wav
# Processing file:  eval\eval_00075.wav
# Processing file:  eval\eval_00076.wav
# Processing file:  eval\eval_00077.wav
# Processing file:  eval\eval_00078.wav
# Processing file:  eval\eval_00079.wav
# Processing file:  eval\eval_00080.wav
# Processing file:  eval\eval_00081.wav
# Processing file:  eval\eval_00082.wav
# Processing file:  eval\eval_00083.wav
# Processing file:  eval\eval_00084.wav
# Processing file:  eval\eval_00085.wav
# Processing file:  eval\eval_00086.wav
# Processing file:  eval\eval_00087.wav
# Processing file:  eval\eval_00088.wav
# Processing file:  eval\eval_00089.wav
# Processing file:  eval\eval_00090.wav
# Processing file:  eval\eval_00091.wav
# Processing file:  eval\eval_00092.wav
# Processing file:  eval\eval_00093.wav
# Processing file:  eval\eval_00094.wav
# Processing file:  eval\eval_00095.wav
# Processing file:  eval\eval_00096.wav
# Processing file:  eval\eval_00097.wav
# Processing file:  eval\eval_00098.wav
# Processing file:  eval\eval_00099.wav
# Processing file:  eval\eval_00100.wav
# Processing file:  eval\eval_00101.wav
# Processing file:  eval\eval_00102.wav
# Processing file:  eval\eval_00103.wav
# Processing file:  eval\eval_00104.wav
# Processing file:  eval\eval_00105.wav
# Processing file:  eval\eval_00106.wav
# Processing file:  eval\eval_00107.wav
# Processing file:  eval\eval_00108.wav
# Processing file:  eval\eval_00109.wav
# Processing file:  eval\eval_00110.wav
# Processing file:  eval\eval_00111.wav
# Processing file:  eval\eval_00112.wav
# Processing file:  eval\eval_00113.wav
# Processing file:  eval\eval_00114.wav
# Processing file:  eval\eval_00115.wav
# Processing file:  eval\eval_00116.wav
# Processing file:  eval\eval_00117.wav
# Processing file:  eval\eval_00118.wav
# Processing file:  eval\eval_00119.wav
# Processing file:  eval\eval_00120.wav
# Processing file:  eval\eval_00121.wav
# Processing file:  eval\eval_00122.wav
# Processing file:  eval\eval_00123.wav
# Processing file:  eval\eval_00124.wav
# Processing file:  eval\eval_00125.wav
# Processing file:  eval\eval_00126.wav
# Processing file:  eval\eval_00127.wav
# Processing file:  eval\eval_00128.wav
# Processing file:  eval\eval_00129.wav
# Processing file:  eval\eval_00130.wav
# Processing file:  eval\eval_00131.wav
# Processing file:  eval\eval_00132.wav
# Processing file:  eval\eval_00133.wav
# Processing file:  eval\eval_00134.wav
# Processing file:  eval\eval_00135.wav
# Processing file:  eval\eval_00136.wav
# Processing file:  eval\eval_00137.wav
# Processing file:  eval\eval_00138.wav
# Processing file:  eval\eval_00139.wav
# Processing file:  eval\eval_00140.wav
# Processing file:  eval\eval_00141.wav
# Processing file:  eval\eval_00142.wav
# Processing file:  eval\eval_00143.wav
# Processing file:  eval\eval_00144.wav
# Processing file:  eval\eval_00145.wav
# Processing file:  eval\eval_00146.wav
# Processing file:  eval\eval_00147.wav
# Processing file:  eval\eval_00148.wav
# Processing file:  eval\eval_00149.wav
# Processing file:  eval\eval_00150.wav
# Processing file:  eval\eval_00151.wav
# Processing file:  eval\eval_00152.wav
# Processing file:  eval\eval_00153.wav
# Processing file:  eval\eval_00154.wav
# Processing file:  eval\eval_00155.wav
# Processing file:  eval\eval_00156.wav
# Processing file:  eval\eval_00157.wav
# Processing file:  eval\eval_00158.wav
# Processing file:  eval\eval_00159.wav
# Processing file:  eval\eval_00160.wav
# Processing file:  eval\eval_00161.wav
# Processing file:  eval\eval_00162.wav
# Processing file:  eval\eval_00163.wav
# Processing file:  eval\eval_00164.wav
# Processing file:  eval\eval_00165.wav
# Processing file:  eval\eval_00166.wav
# Processing file:  eval\eval_00167.wav
# Processing file:  eval\eval_00168.wav
# Processing file:  eval\eval_00169.wav
# Processing file:  eval\eval_00170.wav
# Processing file:  eval\eval_00171.wav
# Processing file:  eval\eval_00172.wav
# Processing file:  eval\eval_00173.wav
# Processing file:  eval\eval_00174.wav
# Processing file:  eval\eval_00175.wav
# Processing file:  eval\eval_00176.wav
# Processing file:  eval\eval_00177.wav
# Processing file:  eval\eval_00178.wav
# Processing file:  eval\eval_00179.wav
# Processing file:  eval\eval_00180.wav
# Processing file:  eval\eval_00181.wav
# Processing file:  eval\eval_00182.wav
# Processing file:  eval\eval_00183.wav
# Processing file:  eval\eval_00184.wav
# Processing file:  eval\eval_00185.wav
# Processing file:  eval\eval_00186.wav
# Processing file:  eval\eval_00187.wav
# Processing file:  eval\eval_00188.wav
# Processing file:  eval\eval_00189.wav
# Processing file:  eval\eval_00190.wav
# Processing file:  eval\eval_00191.wav
# Processing file:  eval\eval_00192.wav
# Processing file:  eval\eval_00193.wav
# Processing file:  eval\eval_00194.wav
# Processing file:  eval\eval_00195.wav
# Processing file:  eval\eval_00196.wav
# Processing file:  eval\eval_00197.wav
# Processing file:  eval\eval_00198.wav
# Processing file:  eval\eval_00199.wav
# Processing file:  eval\eval_00200.wav
# Processing file:  eval\eval_00201.wav
# Processing file:  eval\eval_00202.wav
# Processing file:  eval\eval_00203.wav
# Processing file:  eval\eval_00204.wav
# Processing file:  eval\eval_00205.wav
# Processing file:  eval\eval_00206.wav
# Processing file:  eval\eval_00207.wav
# Processing file:  eval\eval_00208.wav
# Processing file:  eval\eval_00209.wav
# Processing file:  eval\eval_00210.wav
# Processing file:  eval\eval_00211.wav
# Processing file:  eval\eval_00212.wav
# Processing file:  eval\eval_00213.wav
# Processing file:  eval\eval_00214.wav
# Processing file:  eval\eval_00215.wav
# Processing file:  eval\eval_00216.wav
# Processing file:  eval\eval_00217.wav
# Processing file:  eval\eval_00218.wav
# Processing file:  eval\eval_00219.wav
# Processing file:  eval\eval_00220.wav
# Processing file:  eval\eval_00221.wav
# Processing file:  eval\eval_00222.wav
# Processing file:  eval\eval_00223.wav
# Processing file:  eval\eval_00224.wav
# Processing file:  eval\eval_00225.wav
# Processing file:  eval\eval_00226.wav
# Processing file:  eval\eval_00227.wav
# Processing file:  eval\eval_00228.wav
# Processing file:  eval\eval_00229.wav
# Processing file:  eval\eval_00230.wav
# Processing file:  eval\eval_00231.wav
# Processing file:  eval\eval_00232.wav
# Processing file:  eval\eval_00233.wav
# Processing file:  eval\eval_00234.wav
# Processing file:  eval\eval_00235.wav
# Processing file:  eval\eval_00236.wav
# Processing file:  eval\eval_00237.wav
# Processing file:  eval\eval_00238.wav
# Processing file:  eval\eval_00239.wav
# Processing file:  eval\eval_00240.wav
# Processing file:  eval\eval_00241.wav
# Processing file:  eval\eval_00242.wav
# Processing file:  eval\eval_00243.wav
# Processing file:  eval\eval_00244.wav
# Processing file:  eval\eval_00245.wav
# Processing file:  eval\eval_00246.wav
# Processing file:  eval\eval_00247.wav
# Processing file:  eval\eval_00248.wav
# Processing file:  eval\eval_00249.wav
# Processing file:  eval\eval_00250.wav
# Processing file:  eval\eval_00251.wav
# Processing file:  eval\eval_00252.wav
# Processing file:  eval\eval_00253.wav
# Processing file:  eval\eval_00254.wav
# Processing file:  eval\eval_00255.wav
# Processing file:  eval\eval_00256.wav
# Processing file:  eval\eval_00257.wav
# Processing file:  eval\eval_00258.wav
# Processing file:  eval\eval_00259.wav
# Processing file:  eval\eval_00260.wav
# Processing file:  eval\eval_00261.wav
# Processing file:  eval\eval_00262.wav
# Processing file:  eval\eval_00263.wav
# Processing file:  eval\eval_00264.wav
# Processing file:  eval\eval_00265.wav
# Processing file:  eval\eval_00266.wav
# Processing file:  eval\eval_00267.wav
# Processing file:  eval\eval_00268.wav
# Processing file:  eval\eval_00269.wav
# Processing file:  eval\eval_00270.wav
# Processing file:  eval\eval_00271.wav
# Processing file:  eval\eval_00272.wav
# Processing file:  eval\eval_00273.wav
# Processing file:  eval\eval_00274.wav
# Processing file:  eval\eval_00275.wav
# Processing file:  eval\eval_00276.wav
# Processing file:  eval\eval_00277.wav
# Processing file:  eval\eval_00278.wav
# Processing file:  eval\eval_00279.wav
# Processing file:  eval\eval_00280.wav
# Processing file:  eval\eval_00281.wav
# Processing file:  eval\eval_00282.wav
# Processing file:  eval\eval_00283.wav
# Processing file:  eval\eval_00284.wav
# Processing file:  eval\eval_00285.wav
# Processing file:  eval\eval_00286.wav
# Processing file:  eval\eval_00287.wav
# Processing file:  eval\eval_00288.wav
# Processing file:  eval\eval_00289.wav
# Processing file:  eval\eval_00290.wav
# Processing file:  eval\eval_00291.wav
# Processing file:  eval\eval_00292.wav
# Processing file:  eval\eval_00293.wav
# Processing file:  eval\eval_00294.wav
# Processing file:  eval\eval_00295.wav
# Processing file:  eval\eval_00296.wav
# Processing file:  eval\eval_00297.wav
# Processing file:  eval\eval_00298.wav
# Processing file:  eval\eval_00299.wav
# Processing file:  eval\eval_00300.wav
# Processing file:  eval\eval_00301.wav
# Processing file:  eval\eval_00302.wav
# Processing file:  eval\eval_00303.wav
# Processing file:  eval\eval_00304.wav
# Processing file:  eval\eval_00305.wav
# Processing file:  eval\eval_00306.wav
# Processing file:  eval\eval_00307.wav
# Processing file:  eval\eval_00308.wav
# Processing file:  eval\eval_00309.wav
# Processing file:  eval\eval_00310.wav
# Processing file:  eval\eval_00311.wav
# Processing file:  eval\eval_00312.wav
# Processing file:  eval\eval_00313.wav
# Processing file:  eval\eval_00314.wav
# Processing file:  eval\eval_00315.wav
# Processing file:  eval\eval_00316.wav
# Processing file:  eval\eval_00317.wav
# Processing file:  eval\eval_00318.wav
# Processing file:  eval\eval_00319.wav
# Processing file:  eval\eval_00320.wav
# Processing file:  eval\eval_00321.wav
# Processing file:  eval\eval_00322.wav
# Processing file:  eval\eval_00323.wav
# Processing file:  eval\eval_00324.wav
# Processing file:  eval\eval_00325.wav
# Processing file:  eval\eval_00326.wav
# Processing file:  eval\eval_00327.wav
# Processing file:  eval\eval_00328.wav
# Processing file:  eval\eval_00329.wav
# Processing file:  eval\eval_00330.wav
# Processing file:  eval\eval_00331.wav
# Processing file:  eval\eval_00332.wav
# Processing file:  eval\eval_00333.wav
# Processing file:  eval\eval_00334.wav
# Processing file:  eval\eval_00335.wav
# Processing file:  eval\eval_00336.wav
# Processing file:  eval\eval_00337.wav
# Processing file:  eval\eval_00338.wav
# Processing file:  eval\eval_00339.wav
# Processing file:  eval\eval_00340.wav
# Processing file:  eval\eval_00341.wav
# Processing file:  eval\eval_00342.wav
# Processing file:  eval\eval_00343.wav
# Processing file:  eval\eval_00344.wav
# Processing file:  eval\eval_00345.wav
# Processing file:  eval\eval_00346.wav
# Processing file:  eval\eval_00347.wav
# Processing file:  eval\eval_00348.wav
# Processing file:  eval\eval_00349.wav
# Processing file:  eval\eval_00350.wav
# Processing file:  eval\eval_00351.wav
# Processing file:  eval\eval_00352.wav
# Processing file:  eval\eval_00353.wav
# Processing file:  eval\eval_00354.wav
# Processing file:  eval\eval_00355.wav
# Processing file:  eval\eval_00356.wav
# Processing file:  eval\eval_00357.wav
# Processing file:  eval\eval_00358.wav
# Processing file:  eval\eval_00359.wav
# Processing file:  eval\eval_00360.wav
# Processing file:  eval\eval_00361.wav
# Processing file:  eval\eval_00362.wav
# Processing file:  eval\eval_00363.wav
# Processing file:  eval\eval_00364.wav
# Processing file:  eval\eval_00365.wav
# Processing file:  eval\eval_00366.wav
# Processing file:  eval\eval_00367.wav
# Processing file:  eval\eval_00368.wav
# Processing file:  eval\eval_00369.wav
# Processing file:  eval\eval_00370.wav
# Processing file:  eval\eval_00371.wav
# Processing file:  eval\eval_00372.wav
# Processing file:  eval\eval_00373.wav
# Processing file:  eval\eval_00374.wav
# Processing file:  eval\eval_00375.wav
# Processing file:  eval\eval_00376.wav
# Processing file:  eval\eval_00377.wav
# Processing file:  eval\eval_00378.wav
# Processing file:  eval\eval_00379.wav
# Processing file:  eval\eval_00380.wav
# Processing file:  eval\eval_00381.wav
# Processing file:  eval\eval_00382.wav
# Processing file:  eval\eval_00383.wav
# Processing file:  eval\eval_00384.wav
# Processing file:  eval\eval_00385.wav
# Processing file:  eval\eval_00386.wav
# Processing file:  eval\eval_00387.wav
# Processing file:  eval\eval_00388.wav
# Processing file:  eval\eval_00389.wav
# Processing file:  eval\eval_00390.wav
# Processing file:  eval\eval_00391.wav
# Processing file:  eval\eval_00392.wav
# Processing file:  eval\eval_00393.wav
# Processing file:  eval\eval_00394.wav
# Processing file:  eval\eval_00395.wav
# Processing file:  eval\eval_00396.wav
# Processing file:  eval\eval_00397.wav
# Processing file:  eval\eval_00398.wav
# Processing file:  eval\eval_00399.wav
# Processing file:  eval\eval_00400.wav
# Processing file:  eval\eval_00401.wav
# Processing file:  eval\eval_00402.wav
# Processing file:  eval\eval_00403.wav
# Processing file:  eval\eval_00404.wav
# Processing file:  eval\eval_00405.wav
# Processing file:  eval\eval_00406.wav
# Processing file:  eval\eval_00407.wav
# Processing file:  eval\eval_00408.wav
# Processing file:  eval\eval_00409.wav
# Processing file:  eval\eval_00410.wav
# Processing file:  eval\eval_00411.wav
# Processing file:  eval\eval_00412.wav
# Processing file:  eval\eval_00413.wav
# Processing file:  eval\eval_00414.wav
# Processing file:  eval\eval_00415.wav
# Processing file:  eval\eval_00416.wav
# Processing file:  eval\eval_00417.wav
# Processing file:  eval\eval_00418.wav
# Processing file:  eval\eval_00419.wav
# Processing file:  eval\eval_00420.wav
# Processing file:  eval\eval_00421.wav
# Processing file:  eval\eval_00422.wav
# Processing file:  eval\eval_00423.wav
# Processing file:  eval\eval_00424.wav
# Processing file:  eval\eval_00425.wav
# Processing file:  eval\eval_00426.wav
# Processing file:  eval\eval_00427.wav
# Processing file:  eval\eval_00428.wav
# Processing file:  eval\eval_00429.wav
# Processing file:  eval\eval_00430.wav
# Processing file:  eval\eval_00431.wav
# Processing file:  eval\eval_00432.wav
# Processing file:  eval\eval_00433.wav
# Processing file:  eval\eval_00434.wav
# Processing file:  eval\eval_00435.wav
# Processing file:  eval\eval_00436.wav
# Processing file:  eval\eval_00437.wav
# Processing file:  eval\eval_00438.wav
# Processing file:  eval\eval_00439.wav
# Processing file:  eval\eval_00440.wav
# Processing file:  eval\eval_00441.wav
# Processing file:  eval\eval_00442.wav
# Processing file:  eval\eval_00443.wav
# Processing file:  eval\eval_00444.wav
# Processing file:  eval\eval_00445.wav
# Processing file:  eval\eval_00446.wav
# Processing file:  eval\eval_00447.wav
# Processing file:  eval\eval_00448.wav
# Processing file:  eval\eval_00449.wav
# Processing file:  eval\eval_00450.wav
# Processing file:  eval\eval_00451.wav
# Processing file:  eval\eval_00452.wav
# Processing file:  eval\eval_00453.wav
# Processing file:  eval\eval_00454.wav
# Processing file:  eval\eval_00455.wav
# Processing file:  eval\eval_00456.wav
# Processing file:  eval\eval_00457.wav
# Processing file:  eval\eval_00458.wav
# Processing file:  eval\eval_00459.wav
# Processing file:  eval\eval_00460.wav
# Processing file:  eval\eval_00461.wav
# Processing file:  eval\eval_00462.wav
# Processing file:  eval\eval_00463.wav
# Processing file:  eval\eval_00464.wav
# Processing file:  eval\eval_00465.wav
# Processing file:  eval\eval_00466.wav
# Processing file:  eval\eval_00467.wav
# Processing file:  eval\eval_00468.wav
# Processing file:  eval\eval_00469.wav
# Processing file:  eval\eval_00470.wav
# Processing file:  eval\eval_00471.wav
# Processing file:  eval\eval_00472.wav
# Processing file:  eval\eval_00473.wav
# Processing file:  eval\eval_00474.wav
# Processing file:  eval\eval_00475.wav
# Processing file:  eval\eval_00476.wav
# Processing file:  eval\eval_00477.wav
# Processing file:  eval\eval_00478.wav
# Processing file:  eval\eval_00479.wav
# Processing file:  eval\eval_00480.wav
# Processing file:  eval\eval_00481.wav
# Processing file:  eval\eval_00482.wav
# Processing file:  eval\eval_00483.wav
# Processing file:  eval\eval_00484.wav
# Processing file:  eval\eval_00485.wav
# Processing file:  eval\eval_00486.wav
# Processing file:  eval\eval_00487.wav
# Processing file:  eval\eval_00488.wav
# Processing file:  eval\eval_00489.wav
# Processing file:  eval\eval_00490.wav
# Processing file:  eval\eval_00491.wav
# Processing file:  eval\eval_00492.wav
# Processing file:  eval\eval_00493.wav
# Processing file:  eval\eval_00494.wav
# Processing file:  eval\eval_00495.wav
# Processing file:  eval\eval_00496.wav
# Processing file:  eval\eval_00497.wav
# Processing file:  eval\eval_00498.wav
# Processing file:  eval\eval_00499.wav
# Processing file:  eval\eval_00500.wav
# Processing file:  eval\eval_00501.wav
# Processing file:  eval\eval_00502.wav
# Processing file:  eval\eval_00503.wav
# Processing file:  eval\eval_00504.wav
# Processing file:  eval\eval_00505.wav
# Processing file:  eval\eval_00506.wav
# Processing file:  eval\eval_00507.wav
# Processing file:  eval\eval_00508.wav
# Processing file:  eval\eval_00509.wav
# Processing file:  eval\eval_00510.wav
# Processing file:  eval\eval_00511.wav
# Processing file:  eval\eval_00512.wav
# Processing file:  eval\eval_00513.wav
# Processing file:  eval\eval_00514.wav
# Processing file:  eval\eval_00515.wav
# Processing file:  eval\eval_00516.wav
# Processing file:  eval\eval_00517.wav
# Processing file:  eval\eval_00518.wav
# Processing file:  eval\eval_00519.wav
# Processing file:  eval\eval_00520.wav
# Processing file:  eval\eval_00521.wav
# Processing file:  eval\eval_00522.wav
# Processing file:  eval\eval_00523.wav
# Processing file:  eval\eval_00524.wav
# Processing file:  eval\eval_00525.wav
# Processing file:  eval\eval_00526.wav
# Processing file:  eval\eval_00527.wav
# Processing file:  eval\eval_00528.wav
# Processing file:  eval\eval_00529.wav
# Processing file:  eval\eval_00530.wav
# Processing file:  eval\eval_00531.wav
# Processing file:  eval\eval_00532.wav
# Processing file:  eval\eval_00533.wav
# Processing file:  eval\eval_00534.wav
# Processing file:  eval\eval_00535.wav
# Processing file:  eval\eval_00536.wav
# Processing file:  eval\eval_00537.wav
# Processing file:  eval\eval_00538.wav
# Processing file:  eval\eval_00539.wav
# Processing file:  eval\eval_00540.wav
# Processing file:  eval\eval_00541.wav
# Processing file:  eval\eval_00542.wav
# Processing file:  eval\eval_00543.wav
# Processing file:  eval\eval_00544.wav
# Processing file:  eval\eval_00545.wav
# Processing file:  eval\eval_00546.wav
# Processing file:  eval\eval_00547.wav
# Processing file:  eval\eval_00548.wav
# Processing file:  eval\eval_00549.wav
# Processing file:  eval\eval_00550.wav
# Processing file:  eval\eval_00551.wav
# Processing file:  eval\eval_00552.wav
# Processing file:  eval\eval_00553.wav
# Processing file:  eval\eval_00554.wav
# Processing file:  eval\eval_00555.wav
# Processing file:  eval\eval_00556.wav
# Processing file:  eval\eval_00557.wav
# Processing file:  eval\eval_00558.wav
# Processing file:  eval\eval_00559.wav
# Processing file:  eval\eval_00560.wav
# Processing file:  eval\eval_00561.wav
# Processing file:  eval\eval_00562.wav
# Processing file:  eval\eval_00563.wav
# Processing file:  eval\eval_00564.wav
# Processing file:  eval\eval_00565.wav
# Processing file:  eval\eval_00566.wav
# Processing file:  eval\eval_00567.wav
# Processing file:  eval\eval_00568.wav
# Processing file:  eval\eval_00569.wav
# Processing file:  eval\eval_00570.wav
# Processing file:  eval\eval_00571.wav
# Processing file:  eval\eval_00572.wav
# Processing file:  eval\eval_00573.wav
# Processing file:  eval\eval_00574.wav
# Processing file:  eval\eval_00575.wav
# Processing file:  eval\eval_00576.wav
# Processing file:  eval\eval_00577.wav
# Processing file:  eval\eval_00578.wav
# Processing file:  eval\eval_00579.wav
# Processing file:  eval\eval_00580.wav
# Processing file:  eval\eval_00581.wav
# Processing file:  eval\eval_00582.wav
# Processing file:  eval\eval_00583.wav
# Processing file:  eval\eval_00584.wav
# Processing file:  eval\eval_00585.wav
# Processing file:  eval\eval_00586.wav
# Processing file:  eval\eval_00587.wav
# Processing file:  eval\eval_00588.wav
# Processing file:  eval\eval_00589.wav
# Processing file:  eval\eval_00590.wav
# Processing file:  eval\eval_00591.wav
# Processing file:  eval\eval_00592.wav
# Processing file:  eval\eval_00593.wav
# Processing file:  eval\eval_00594.wav
# Processing file:  eval\eval_00595.wav
# Processing file:  eval\eval_00596.wav
# Processing file:  eval\eval_00597.wav
# Processing file:  eval\eval_00598.wav
# Processing file:  eval\eval_00599.wav
# Processing file:  eval\eval_00600.wav
# Processing file:  eval\eval_00601.wav
# Processing file:  eval\eval_00602.wav
# Processing file:  eval\eval_00603.wav
# Processing file:  eval\eval_00604.wav
# Processing file:  eval\eval_00605.wav
# Processing file:  eval\eval_00606.wav
# Processing file:  eval\eval_00607.wav
# Processing file:  eval\eval_00608.wav
# Processing file:  eval\eval_00609.wav
# Processing file:  eval\eval_00610.wav
# Processing file:  eval\eval_00611.wav
# Processing file:  eval\eval_00612.wav
# Processing file:  eval\eval_00613.wav
# Processing file:  eval\eval_00614.wav
# Processing file:  eval\eval_00615.wav
# Processing file:  eval\eval_00616.wav
# Processing file:  eval\eval_00617.wav
# Processing file:  eval\eval_00618.wav
# Processing file:  eval\eval_00619.wav
# Processing file:  eval\eval_00620.wav
# Processing file:  eval\eval_00621.wav
# Processing file:  eval\eval_00622.wav
# Processing file:  eval\eval_00623.wav
# Processing file:  eval\eval_00624.wav
# Processing file:  eval\eval_00625.wav
# Processing file:  eval\eval_00626.wav
# Processing file:  eval\eval_00627.wav
# Processing file:  eval\eval_00628.wav
# Processing file:  eval\eval_00629.wav
# Processing file:  eval\eval_00630.wav
# Processing file:  eval\eval_00631.wav
# Processing file:  eval\eval_00632.wav
# Processing file:  eval\eval_00633.wav
# Processing file:  eval\eval_00634.wav
# Processing file:  eval\eval_00635.wav
# Processing file:  eval\eval_00636.wav
# Processing file:  eval\eval_00637.wav
# Processing file:  eval\eval_00638.wav
# Processing file:  eval\eval_00639.wav
# Processing file:  eval\eval_00640.wav
# Processing file:  eval\eval_00641.wav
# Processing file:  eval\eval_00642.wav
# Processing file:  eval\eval_00643.wav
# Processing file:  eval\eval_00644.wav
# Processing file:  eval\eval_00645.wav
# Processing file:  eval\eval_00646.wav
# Processing file:  eval\eval_00647.wav
# Processing file:  eval\eval_00648.wav
# Processing file:  eval\eval_00649.wav
# Processing file:  eval\eval_00650.wav
# Processing file:  eval\eval_00651.wav
# Processing file:  eval\eval_00652.wav
# Processing file:  eval\eval_00653.wav
# Processing file:  eval\eval_00654.wav
# Processing file:  eval\eval_00655.wav
# Processing file:  eval\eval_00656.wav
# Processing file:  eval\eval_00657.wav
# Processing file:  eval\eval_00658.wav
# Processing file:  eval\eval_00659.wav
# Processing file:  eval\eval_00660.wav
# Processing file:  eval\eval_00661.wav
# Processing file:  eval\eval_00662.wav
# Processing file:  eval\eval_00663.wav
# Processing file:  eval\eval_00664.wav
# Processing file:  eval\eval_00665.wav
# Processing file:  eval\eval_00666.wav
# Processing file:  eval\eval_00667.wav
# Processing file:  eval\eval_00668.wav
# Processing file:  eval\eval_00669.wav
# Processing file:  eval\eval_00670.wav
# Processing file:  eval\eval_00671.wav
# Processing file:  eval\eval_00672.wav
# Processing file:  eval\eval_00673.wav
# Processing file:  eval\eval_00674.wav
# Processing file:  eval\eval_00675.wav
# Processing file:  eval\eval_00676.wav
# Processing file:  eval\eval_00677.wav
# Processing file:  eval\eval_00678.wav
# Processing file:  eval\eval_00679.wav
# Processing file:  eval\eval_00680.wav
# Processing file:  eval\eval_00681.wav
# Processing file:  eval\eval_00682.wav
# Processing file:  eval\eval_00683.wav
# Processing file:  eval\eval_00684.wav
# Processing file:  eval\eval_00685.wav
# Processing file:  eval\eval_00686.wav
# Processing file:  eval\eval_00687.wav
# Processing file:  eval\eval_00688.wav
# Processing file:  eval\eval_00689.wav
# Processing file:  eval\eval_00690.wav
# Processing file:  eval\eval_00691.wav
# Processing file:  eval\eval_00692.wav
# Processing file:  eval\eval_00693.wav
# Processing file:  eval\eval_00694.wav
# Processing file:  eval\eval_00695.wav
# Processing file:  eval\eval_00696.wav
# Processing file:  eval\eval_00697.wav
# Processing file:  eval\eval_00698.wav
# Processing file:  eval\eval_00699.wav
# Processing file:  eval\eval_00700.wav
# Processing file:  eval\eval_00701.wav
# Processing file:  eval\eval_00702.wav
# Processing file:  eval\eval_00703.wav
# Processing file:  eval\eval_00704.wav
# Processing file:  eval\eval_00705.wav
# Processing file:  eval\eval_00706.wav
# Processing file:  eval\eval_00707.wav
# Processing file:  eval\eval_00708.wav
# Processing file:  eval\eval_00709.wav
# Processing file:  eval\eval_00710.wav
# Processing file:  eval\eval_00711.wav
# Processing file:  eval\eval_00712.wav
# Processing file:  eval\eval_00713.wav
# Processing file:  eval\eval_00714.wav
# Processing file:  eval\eval_00715.wav
# Processing file:  eval\eval_00716.wav
# Processing file:  eval\eval_00717.wav
# Processing file:  eval\eval_00718.wav
# Processing file:  eval\eval_00719.wav
# Processing file:  eval\eval_00720.wav
# Processing file:  eval\eval_00721.wav
# Processing file:  eval\eval_00722.wav
# Processing file:  eval\eval_00723.wav
# Processing file:  eval\eval_00724.wav
# Processing file:  eval\eval_00725.wav
# Processing file:  eval\eval_00726.wav
# Processing file:  eval\eval_00727.wav
# Processing file:  eval\eval_00728.wav
# Processing file:  eval\eval_00729.wav
# Processing file:  eval\eval_00730.wav
# Processing file:  eval\eval_00731.wav
# Processing file:  eval\eval_00732.wav
# Processing file:  eval\eval_00733.wav
# Processing file:  eval\eval_00734.wav
# Processing file:  eval\eval_00735.wav
# Processing file:  eval\eval_00736.wav
#
# Spracovanie súborov v eval adresári: eval
# Eval: audio_GMM_sklearn_eval.txt
